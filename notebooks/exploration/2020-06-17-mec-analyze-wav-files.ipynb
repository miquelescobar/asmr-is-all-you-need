# %%
import sys
sys.path.append('../../network/models')

# %%
import librosa
import librosa.display
import wavenet

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
audio = wavenet.data.load_audio('../../data/processed/tapping/tapping-glass/PLhDdb5CgZ4-hour-glass-2.wav')
# Out:
# ../../data/processed/tapping/tapping-glass/PLhDdb5CgZ4-hour-glass-2.wav

# %%
plt.plot(audio)

# %%
x, sr = librosa.load('../../data/processed/tapping/tapping-glass/PLhDdb5CgZ4-hour-glass-2.wav')
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)

# %%
librosa.output.write_wav('./demo.wav', audio, sr)
